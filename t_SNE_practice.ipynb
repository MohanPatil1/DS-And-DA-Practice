# %% [markdown]
# <a href="https://colab.research.google.com/github/MohanPatil1/DS-And-DA-Assignments/blob/main/t_SNE_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bioinfokit

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
from bioinfokit.visuz import cluster

# %%
df = pd.read_csv('/content/TSNE_data.csv')

# %%
df.head() # M - Malignant - cancer Tumor present ,B Benign-not cancer tumor present
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
array = df.values
X = array[:,1:]
Y = array[:,0]

# %%
df
# Out:
#     diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0           M        17.99  ...          0.4601                  0.11890
# 1           M        20.57  ...          0.2750                  0.08902
# 2           M        19.69  ...          0.3613                  0.08758
# 3           M        11.42  ...          0.6638                  0.17300
# 4           M        20.29  ...          0.2364                  0.07678
# ..        ...          ...  ...             ...                      ...
# 564         M        21.56  ...          0.2060                  0.07115
# 565         M        20.13  ...          0.2572                  0.06637
# 566         M        16.60  ...          0.2218                  0.07820
# 567         M        20.60  ...          0.4087                  0.12400
# 568         B         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
# TSNE visualization
data_tsne=TSNE(n_components=2).fit_transform(X)
cluster.tsneplot(score=data_tsne)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
data_tsne
# Out:
# array([[ 41.36466  , -12.325901 ],
#        [ 41.467167 ,  -9.637534 ],
#        [ 36.921112 ,  -9.794169 ],
#        ...,
#        [ 21.57033  ,  -2.9216082],
#        [ 39.370033 ,  -9.766701 ],
#        [-37.38704  , -25.244577 ]], dtype=float32)

# %%
newdf=pd.DataFrame(data_tsne).join(df['diagnosis'])
newdf
# Out:
#              0          1 diagnosis
# 0    41.364658 -12.325901         M
# 1    41.467167  -9.637534         M
# 2    36.921112  -9.794169         M
# 3   -17.652138   2.364872         M
# 4    35.760651  -7.738987         M
# ..         ...        ...       ...
# 564  42.969425  -8.990262         M
# 565  37.833145  -9.169492         M
# 566  21.570330  -2.921608         M
# 567  39.370033  -9.766701         M
# 568 -37.387039 -25.244577         B
#
# [569 rows x 3 columns]

# %%
color_class =df['diagnosis'].to_numpy()
cluster.tsneplot(score=data_tsne,colorlist=color_class,legendpos='upper right',legendanchor=(1.15,1))

# %%
color_class
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
# ...
